# %%
import urllib.request
import urllib, urllib.parse
import json
from datetime import datetime, timedelta
import os
import urllib.parse
import csv
import unicodedata
import io
import time
import numpy as np 
from IPython.core.interactiveshell import InteractiveShell

# load libraries
from multiprocessing import freeze_support
from multiprocessing import Pool
from functools import partial
import threading
import math
import pandas as pd
import numpy as np
from random import randint
from time import sleep

import datetime, xlrd
import pandas as pd # for later
import time
import csv
import rdflib
from SPARQLWrapper import SPARQLWrapper, JSON
import datetime, xlrd
    
# function to get unique values
def unique(list1): 
    x = np.array(list1) 
    return np.unique(x) 

def get_artist_info_fromDBpedia_getartists():
    file_path = '..//Lastfmlovedtracks.csv'
    list3 = []
    #list.append(lastfm_username)
    #try:
    ifile  = open(file_path, "r")
    read = csv.reader(ifile)
    if os.stat(file_path).st_size == 0:
        return list3
    else:
        for row in read :
            list3.append(row[4])
        return unique(list3)
    #except:
     #   return list
    
def get_artist_info_fromDBpedia_activeYearsStartYear(artist):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    artist_ = artist.replace(" ", "_")
    sparql.setQuery("""
            SELECT  
            (COALESCE(?activeYearsStartYear, "empty") as ?activeYearsStartYear) 

            WHERE
             {
              SELECT  
               (SAMPLE(?activeYearsStartYear) AS ?activeYearsStartYear)
              WHERE {
                OPTIONAL {<http://dbpedia.org/resource/"""+artist_+"""> dbo:activeYearsStartYear ?activeYearsStartYear.}
                     } 
             }
        """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    file_path = '..//Artist_WithDBpedia_activeYearsStartYear.csv'
    tracks_data = open(file_path, '+a' , newline='')
    csvwriter = csv.writer(tracks_data)

    for result in results["results"]["bindings"]:
        try:
            csvwriter.writerow([str(artist) ,
                                str(result["activeYearsStartYear"]["value"]).replace("^^<http://www.w3.org/2001/XMLSchema#gYear>", "")])
        except Exception as e:
            print(e)
            pass

    return 0
    
def get_artist_info_fromDBpedia_associatedband(artist):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    artist_ = artist.replace(" ", "_")
    sparql.setQuery("""
            SELECT  
            (COALESCE(?associatedBand, "empty") as ?associatedBand) 

            WHERE
             {
              SELECT  
               (SAMPLE(?associatedBand) AS ?associatedBand)
              WHERE {
                OPTIONAL {<http://dbpedia.org/resource/"""+artist_+"""> dbo:associatedBand  ?associatedBand.}
                     } 
             }
        """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    file_path = '..//Artist_WithDBpedia_associatedband.csv'
    tracks_data = open(file_path, '+a' , newline='')
    csvwriter = csv.writer(tracks_data)

    for result in results["results"]["bindings"]:
        try:
            csvwriter.writerow([str(artist) ,
                                str(result["associatedBand"]["value"]).replace("http://dbpedia.org/resource/", "")])
        except Exception as e:
            print(e)
            pass

    return 0

def get_artist_info_fromDBpedia_associatedmusicalartist(artist):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    artist_ = artist.replace(" ", "_")
    sparql.setQuery("""
            SELECT  
            (COALESCE(?associatedMusicalArtist, "empty") as ?associatedMusicalArtist) 

            WHERE
             {
              SELECT  
               (SAMPLE(?associatedMusicalArtist) AS ?associatedMusicalArtist)
              WHERE {
                OPTIONAL {<http://dbpedia.org/resource/"""+artist_+"""> dbo:associatedMusicalArtist ?associatedMusicalArtist.}
                     } 
             }
        """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert() 
    file_path = '..//Artist_WithDBpedia_associatedmusicalartist.csv'
    tracks_data = open(file_path, '+a' , newline='')
    csvwriter = csv.writer(tracks_data)

    for result in results["results"]["bindings"]:
        try:
            csvwriter.writerow([str(artist) ,
                                str(result["associatedMusicalArtist"]["value"]).replace("http://dbpedia.org/resource/", "")])
        except Exception as e:
            print(e)
            pass

    return 0

def get_artist_info_fromDBpedia_background(artist):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    artist_ = artist.replace(" ", "_")
    sparql.setQuery("""
            SELECT  
            (COALESCE(?background, "empty") as ?background) 

            WHERE
             {
              SELECT  
               (SAMPLE(?background) AS ?background)
              WHERE {
                OPTIONAL {<http://dbpedia.org/resource/"""+artist_+"""> dbo:background ?background.}
                     } 
             }
        """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    file_path = '..//Artist_WithDBpedia_background.csv'
    tracks_data = open(file_path, '+a' , newline='')
    csvwriter = csv.writer(tracks_data)

    for result in results["results"]["bindings"]:
        try:
            csvwriter.writerow([str(artist) ,
                                str(result["background"]["value"])])
        except Exception as e:
            print(e)
            pass

    return 0

def get_artist_info_fromDBpedia_birthdate(artist):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    artist_ = artist.replace(" ", "_")
    sparql.setQuery("""
            SELECT  
            (COALESCE(?birthDate, "empty") as ?birthDate) 

            WHERE
             {
              SELECT  
               (SAMPLE(?birthDate) AS ?birthDate)
              WHERE {
                OPTIONAL {<http://dbpedia.org/resource/"""+artist_+"""> dbo:birthDate ?birthDate.}
                     } 
             }
        """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    file_path = '..//Artist_WithDBpedia_birthdate.csv'
    tracks_data = open(file_path, '+a' , newline='')
    csvwriter = csv.writer(tracks_data)

    for result in results["results"]["bindings"]:
        try:
            csvwriter.writerow([str(artist) ,
                                    str(result["birthDate"]["value"])])
        except Exception as e:
            print(e)
            pass

    return 0

def get_artist_info_fromDBpedia_birthplace(artist):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    artist_ = artist.replace(" ", "_")
    sparql.setQuery("""
            SELECT  
            (COALESCE(?birthPlace, "empty") as ?birthPlace) 

            WHERE
             {
              SELECT  
               (SAMPLE(?birthPlace) AS ?birthPlace)
              WHERE {
                OPTIONAL {<http://dbpedia.org/resource/"""+artist_+"""> dbo:birthPlace ?birthPlace.}
                     } 
             }
        """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    file_path = '..//Artist_WithDBpedia_birthplace.csv'
    tracks_data = open(file_path, '+a' , newline='')
    csvwriter = csv.writer(tracks_data)

    for result in results["results"]["bindings"]:
        try:
            csvwriter.writerow([str(artist) ,
                                    str(result["birthPlace"]["value"]).replace("http://dbpedia.org/resource/", "")])
        except Exception as e:
            print(e)
            pass

    return 0

def get_artist_info_fromDBpedia_genre(artist):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    artist_ = artist.replace(" ", "_")
    sparql.setQuery("""
            SELECT  
            (COALESCE(?genre, "empty") as ?genre) 

            WHERE
             {
              SELECT  
               (SAMPLE(?genre) AS ?genre)
              WHERE {
                OPTIONAL {<http://dbpedia.org/resource/"""+artist_+"""> dbo:genre ?genre.}
                     } 
             }
        """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    file_path = '..//Artist_WithDBpedia_genre.csv'
    tracks_data = open(file_path, '+a' , newline='')
    csvwriter = csv.writer(tracks_data)

    for result in results["results"]["bindings"]:
        try:
            csvwriter.writerow([str(artist) ,
                                    str(result["genre"]["value"]).replace("http://dbpedia.org/resource/", "")])
        except Exception as e:
            print(e)
            pass

    return 0

def get_artist_info_fromDBpedia_subject(artist):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    artist_ = artist.replace(" ", "_")
    sparql.setQuery("""
            SELECT  
            (COALESCE(?subject, "empty") as ?subject) 

            WHERE
             {
              SELECT  
               (SAMPLE(?subject) AS ?subject)
              WHERE {
                OPTIONAL {<http://dbpedia.org/resource/"""+artist_+"""> dct:subject ?subject.}
                     } 
             }
        """)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    file_path = '..//Artist_WithDBpedia_subject.csv'
    tracks_data = open(file_path, '+a' , newline='')
    csvwriter = csv.writer(tracks_data)

    for result in results["results"]["bindings"]:
        try:
            csvwriter.writerow([str(artist) ,
                                    str(result["subject"]["value"]).replace("http://dbpedia.org/resource/Category:", "")])
        except Exception as e:
            print(e)
            pass

    return 0

def get_artist_info_fromDBpedia(art):
    try:
        get_artist_info_fromDBpedia_subject(art) 
        get_artist_info_fromDBpedia_genre(art)
        get_artist_info_fromDBpedia_background(art)
        get_artist_info_fromDBpedia_birthdate(art)
        get_artist_info_fromDBpedia_birthplace(art)
        get_artist_info_fromDBpedia_associatedmusicalartist(art)
        get_artist_info_fromDBpedia_associatedband(art)
        get_artist_info_fromDBpedia_activeYearsStartYear(art)

        i+=1
    except Exception as e:
        print(e)
        continue

# %%
artist_list = get_artist_info_fromDBpedia_getartists()

for art in artist_list:
    get_artist_info_fromDBpedia(art)
